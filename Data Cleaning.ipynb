# %%
from sqlalchemy import create_engine
import pymysql

# %%
engine=create_engine('mysql+pymysql://root:Mysql%40123321@localhost:3306/db_cleaning')
try:
    engine
    print("connectino successful")
except:
    print('connection failed')
# Out:
# connectino successful

# %%
conn=engine.connect()

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Siddharth Singh\Desktop\ \Data Cleaning\customer_orders.csv")

# %%
df.head()
# Out:
#    order_id   customer_name                 email  order_date  \
# 0      1001      John Smith  john.smith@gmail.com  2023-11-02
# 1      1002      john smith  john.smith@gmail.com  11/02/2023
# 2      1003  SARAH THOMPSON     sarah.t@gmail.com  2023/10/30
# 3      1004     Tom O'Brien                   NaN  2023-11-05
# 4      1005    Mary Johnson      mary.j@gmail.com  2023-11-06
#
#          product_name quantity    price         country order_status  \
# 0         Apple Watch        1   399.99             usa    Delivered
# 1         apple watch        1  $399.99             USA    delivered
# 2  Samsung Galaxy S22      two      799   United States      shipped
# 3        Google Pixel        1      599              UK    Delivered
# 4  Samsung Galaxy S22        2      800  United Kingdom     returned
#
#                          notes
# 0                            -
# 1              Duplicate name?
# 2  "customer requested refund"
# 3                          NaN
# ...

# %%
df.to_sql('cust_ord',index=False, con=conn, if_exists='replace')
# Out:
# 15

# %%
df.shape
# Out:
# (15, 10)
